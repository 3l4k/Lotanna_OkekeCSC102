# %% [markdown]
# # Lotanna Okeke
# ## 20120612038
# ### lotanna.okeke@pau.edu.ng
# #### Class Exercise

# %% [markdown]
# # Exercise 1
#
# ##### Write a python program to get the difference between a given number and 17, if the given number is greater than 17 return double the absolute diference
#
# ![exercise%201.jpg](attachment:exercise%201.jpg)

# %%
a = int(input("Enter a number "))
# a = 12
b = a-17
c = b*2
d = -b
if b < 0:
    print(d)
else:
    print(c)
# Out:
# Enter a number 2
# 15

# %% [markdown]
# # Exercise 2
#
# ##### Write a python program to calculate the sum of the three given numbers, if thr value are equal then requre thrice of their sum
#
# ![Exercise%202.jpg](attachment:Exercise%202.jpg)

# %%
a = int(input("Enter a number "))
b = int(input("Enter a number "))
c = int(input("Enter a number "))
d = a+b+c
e = d*3
if a == b == c:
    print(e)
else:
    print(d)
# Out:
# Enter a number 3
# Enter a number 3
# Enter a number 3
# 27

# %% [markdown]
# # Exericise 3
#
# ##### Wite a python program which will return true if the two given integer value are equal ofr their sum or difference is 5
# ![exercise%203jpg.jpg](attachment:exercise%203jpg.jpg)

# %%
a = int(input("Enter a number "))
b = int(input("Enter a number "))
c = a+b
d = a-b
if a==b:
    print("True")
elif c==5:
    print("True")
elif d==5:
    print("True")
else:
    print("False")
# Out:
# Enter a number 5
# Enter a number 2
# False

# %% [markdown]
# # Exercise 4
#
# ##### Write a python program to sort three integers without using conditional statements and loops
# ![exercise%204.jpg](attachment:exercise%204.jpg)

# %%
a = int(input("Enter a number "))
b = int(input("Enter a number "))
c = int(input("Enter a number "))
d = min(a, b, c)
e = max(a, b, c)
f = (a+b+c)-(d+e)
print("Maximum = ", e, " Middle = ", f, " Minimum = ", d )
# Out:
# Enter a number 12
# Enter a number 13
# Enter a number 134
# Maximum =  134  Middle =  13  Minimum =  12

# %% [markdown]
# # Exercise 5
#
# ##### Write a python program that takes a postive interger and returns the sum of the cube of all the postive integers smaller than the specified number
# ![exercise%205.jpg](attachment:exercise%205.jpg)

# %%
a = int(input("Enter a number "))
d = 0
# b = range(1,a)
b = 1
e = range(1,a)
for b in e:
#     d = 0
    c = b*b*b
    d = d + c
print(d)
# Out:
# Enter a number 3
# 9
